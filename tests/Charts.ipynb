# %%
# HIDDEN
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %load_ext autoreload
# %autoreload 2

# %%
from bokeh.sampledata.autompg import autompg as df
t = Table.from_df(df)

# %%
t.group('yr').plot('yr')

# %%
t.plot('weight', ['displ', 'hp'])

# %%
t.with_column('big weight', t['weight'] * 1000).plot('big weight', ['hp', 'displ'])

# %%
t.plot('weight', ['hp', 'displ'], overlay=False)

# %%
t.group_bar('cyl')

# %%
t.group('cyl').bar('cyl')

# %%
t.select(['cyl', 'displ', 'hp']).group('cyl', max).bar('cyl')

# %%
t.group('cyl', max).bar('cyl', [1, 2, 3])

# %%
t.group('cyl', max).bar('cyl', [1, 2, 3], overlay=False)

# %%
t.group_barh('cyl')

# %%
t.group('cyl').barh('cyl')

# %%
t.select(['cyl', 'displ', 'hp']).group('cyl', max).barh('cyl')

# %%
t.group('cyl', max).barh('cyl', [1, 2, 3])

# %%
t.group('cyl', max).barh('cyl', [1, 2, 3], overlay=False)

# %%
t.select(['weight', 'displ', 'hp']).scatter('weight')

# %%
t.select(['weight', 'displ', 'hp']).scatter('weight', fit_line=True)

# %%
t.select(['weight', 'displ', 'hp']).scatter('weight', fit_line=True, overlay=False)

# %%
t.scatter('weight', 'hp')

# %%
t.scatter('weight', [2, 3])

# %%
t.with_column('big weight', t['weight'] * 1000).scatter('big weight', 'hp')

# %%
t.scatter('weight', ['displ', 'hp'])

# %%
t.scatter('weight', ['displ', 'hp'], overlay=False)

# %%
t.drop('name').scatter('weight', 'displ', sizes='hp', s=200, colors='cyl')

# %%
t.hist('mpg')
# Out:
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
f = t.hist('mpg', normed=False)

# %%
t.hist('mpg', overlay=False)

# %%
f = t.with_column('mpg2', t['mpg'] * 10000).hist('mpg2')

# %%
f = t.with_column('mpg2', t['mpg'] * 10000).hist('mpg2', bins=100)

# %%
t.hist(['displ', 'hp'])

# %%
t.hist(['displ', 'hp'], overlay=False)

# %%
bins = np.append(np.arange(0, 200, 20), np.arange(200, 501, 50))
t.hist('displ', bins=bins, unit='cc')

# %%
t.with_column('displ-µm3', t['displ'] * 10000).hist('displ-µm3', bins=bins*10000, unit='µm3')
# Out:
# Error in callback <function post_execute at 0x7ff56ba088c0> (for post_execute):
# ValueErrorTraceback (most recent call last)
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in post_execute()
#     147             def post_execute():
#     148                 if matplotlib.is_interactive():
# --> 149                     draw_all()
#     150
#     151             # IPython >= 2
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/_pylab_helpers.pyc in draw_all(cls, force)
#     134         for f_mgr in cls.get_all_fig_managers():
#     135             if force or f_mgr.canvas.figure.stale:
# --> 136                 f_mgr.canvas.draw_idle()
#     137
#     138 atexit.register(Gcf.destroy_all)
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
#    2054             with self._idle_draw_cntx():
# -> 2055                 self.draw(*args, **kwargs)
#    2056
#    2057     def draw_cursor(self, event):
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     431             # if toolbar:
#     432             #     toolbar.set_cursor(cursors.WAIT)
# --> 433             self.figure.draw(self.renderer)
#     434             # A GUI class may be need to update a window using this draw, so
#     435             # don't forget to call the superclass.
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1473
#    1474             mimage._draw_list_compositing_images(
# -> 1475                 renderer, self, artists, self.suppressComposite)
#    1476
#    1477             renderer.close_group('figure')
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2605             renderer.stop_rasterizing()
#    2606
# -> 2607         mimage._draw_list_compositing_images(renderer, self, artists)
#    2608
#    2609         renderer.close_group('axes')
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/axis.pyc in draw(self, renderer, *args, **kwargs)
#    1202         self._update_label_position(renderer)
#    1203
# -> 1204         self.label.draw(renderer)
#    1205
#    1206         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/text.pyc in draw(self, renderer)
#     704
#     705         with _wrap_text(self) as textobj:
# --> 706             bbox, info, descent = textobj._get_layout(renderer)
#     707             trans = textobj.get_transform()
#     708
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/text.pyc in _get_layout(self, renderer)
#     303         baseline = 0
#     304         for i, line in enumerate(lines):
# --> 305             clean_line, ismath = self.is_math_text(line, self.get_usetex())
#     306             if clean_line:
#     307                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/text.pyc in is_math_text(s, usetex)
#    1186             return s, 'TeX'
#    1187
# -> 1188         if cbook.is_math_text(s):
#    1189             return s, True
#    1190         else:
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/cbook/__init__.pyc in is_math_text(s)
#    2031     except UnicodeDecodeError:
#    2032         raise ValueError(
# -> 2033             "matplotlib display text must have all code points < 128 or use "
#    2034             "Unicode strings")
#    2035
#
# ValueError: matplotlib display text must have all code points < 128 or use Unicode strings
# ValueErrorTraceback (most recent call last)
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     332                 pass
#     333             else:
# --> 334                 return printer(obj)
#     335             # Finally look for special method names
#     336             method = get_real_method(obj, self.print_method)
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/backend_bases.pyc in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2210                     orientation=orientation,
#    2211                     dryrun=True,
# -> 2212                     **kwargs)
#    2213                 renderer = self.figure._cachedRenderer
#    2214                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in print_png(self, filename_or_obj, *args, **kwargs)
#     511
#     512     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 513         FigureCanvasAgg.draw(self)
#     514         renderer = self.get_renderer()
#     515         original_dpi = renderer.dpi
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/backends/backend_agg.pyc in draw(self)
#     431             # if toolbar:
#     432             #     toolbar.set_cursor(cursors.WAIT)
# --> 433             self.figure.draw(self.renderer)
#     434             # A GUI class may be need to update a window using this draw, so
#     435             # don't forget to call the superclass.
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/figure.pyc in draw(self, renderer)
#    1473
#    1474             mimage._draw_list_compositing_images(
# -> 1475                 renderer, self, artists, self.suppressComposite)
#    1476
#    1477             renderer.close_group('figure')
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in draw(self, renderer, inframe)
#    2605             renderer.stop_rasterizing()
#    2606
# -> 2607         mimage._draw_list_compositing_images(renderer, self, artists)
#    2608
#    2609         renderer.close_group('axes')
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/image.pyc in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     139     if not_composite or not has_images:
#     140         for a in artists:
# --> 141             a.draw(renderer)
#     142     else:
#     143         # Composite any adjacent images together
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/axis.pyc in draw(self, renderer, *args, **kwargs)
#    1202         self._update_label_position(renderer)
#    1203
# -> 1204         self.label.draw(renderer)
#    1205
#    1206         self._update_offset_text_position(ticklabelBoxes, ticklabelBoxes2)
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/artist.pyc in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/text.pyc in draw(self, renderer)
#     704
#     705         with _wrap_text(self) as textobj:
# --> 706             bbox, info, descent = textobj._get_layout(renderer)
#     707             trans = textobj.get_transform()
#     708
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/text.pyc in _get_layout(self, renderer)
#     303         baseline = 0
#     304         for i, line in enumerate(lines):
# --> 305             clean_line, ismath = self.is_math_text(line, self.get_usetex())
#     306             if clean_line:
#     307                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/text.pyc in is_math_text(s, usetex)
#    1186             return s, 'TeX'
#    1187
# -> 1188         if cbook.is_math_text(s):
#    1189             return s, True
#    1190         else:
#
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/venvs/local/lib/python2.7/site-packages/matplotlib/cbook/__init__.pyc in is_math_text(s)
#    2031     except UnicodeDecodeError:
#    2032         raise ValueError(
# -> 2033             "matplotlib display text must have all code points < 128 or use "
#    2034             "Unicode strings")
#    2035
#
# ValueError: matplotlib display text must have all code points < 128 or use Unicode strings

# %%
t.with_column('weight-1000', t['weight']-1000).hist(['weight', 'weight-1000'], unit='kg', width=4, height=3)

# %%
two_cats = t.with_column('cat', t['hp'] > 100)
two_cats.hist('mpg', group='cat')

# %%
more_cats = t.with_column('cat', [str(c) for c in (t['hp'] > 100).astype(int) + (t['hp'] > 120).astype(int)])
more_cats.hist('mpg', group='cat')

# %%
more_cats.hist('mpg', group='cat', overlay=False)

# %%
more_cats.pivot_hist('cat', 'mpg')
# Out:
# /media/amontesb/HITACHI/Alex Montes/Documents/GitHub/datascience/datascience/tables.py:2342: UserWarning: pivot_hist is deprecated; use hist(value_column_label, group=pivot_column_label), or with side_by_side=True if you really want side-by-side bars.
#   warnings.warn("pivot_hist is deprecated; use "

# %%
more_cats.hist('mpg', group='cat', side_by_side=True)
